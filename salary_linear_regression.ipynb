# %%
import numpy as np  
import matplotlib.pyplot as mtp  
import pandas as pd  
from sklearn.model_selection import train_test_split  
from sklearn.linear_model import LinearRegression  
from sklearn.metrics import mean_squared_error, r2_score

# Load the salary dataset
file_path = 'Salary_dataset.csv'
salary_data = pd.read_csv(file_path)

# Define the independent (YearsExperience) and dependent (Salary) variables
x = salary_data[['YearsExperience']].values
y = salary_data['Salary'].values

# Split the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=0)

# Create a linear regression model and train it
regressor = LinearRegression()
regressor.fit(x_train, y_train)

# Predict salary for the test and train sets
y_pred = regressor.predict(x_test)
x_pred = regressor.predict(x_train)

# Plot the training set results
mtp.scatter(x_train, y_train, color="green")
mtp.plot(x_train, x_pred, color="red")
mtp.title("Linear Regression on Salary Dataset (Training Set)")
mtp.xlabel("Years of Experience")
mtp.ylabel("Salary")
mtp.show()

# Plot the testing set results
mtp.scatter(x_test, y_test, color="blue")
mtp.plot(x_train, x_pred, color="red")
mtp.title("Linear Regression on Salary Dataset (Testing Set)")
mtp.xlabel("Years of Experience")
mtp.ylabel("Salary")
mtp.show()

# Output model coefficients and performance
print('Coefficients:', regressor.coef_)
print('Intercept:', regressor.intercept_)
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Coefficient of Determination (R^2 Score):', r2_score(y_test, y_pred))
# Out:
# Coefficients: [9345.94244312]
# Intercept: 25882.59799971892
# Mean Squared Error: 21026037.329511236
# Coefficient of Determination (R^2 Score): 0.9749154407708353
